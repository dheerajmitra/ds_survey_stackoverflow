# %% [markdown]
# # Data Analysis on Stack overflow survey

# %% [raw]
# I used CRISDM appoarch In which following points are considered
#    1 Business understanding: outline the questions you will answer along with why they are relevant and important
#    2 Data understanding: provide some stats about your data like mean and std deviations of the different features
#    3 Data preparation: show how you clean and prepare the data. It is important to document and not just write the code
#    4 Data modeling: if you created a model this is the section you would put it in or the analysis
#    5 Results evaluation: conclusion and discussion

# %% [markdown]
# Business Understanding:These question are related to Bootcamp,Data Scientist and lifestyle of developers I try to figure out the relations between the attributes and and explain the importance in my result at end of evrey question

# %% [markdown]
# Data understanding :I tried to explain stats by showing their no. in data set and Probabiltiy and calculate some ratio for comparison like I tried to start with Gender who takes survey

# %% [markdown]
# Data perpartion : Data is prepared by cleaning and I tried to removing missing value and try to clean data and make more precise for calculations

# %% [markdown]
# Data modeling: I did'nt use any machine leanring model because my question are can be complete by Data analysis

# %% [markdown]
# Result evalution : I had concluded all the result in my blog You can check here https://medium.com/@dheerajmitra18/data-scientist-and-remote-developer-627ccc06850d

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ALookAtTheData as t
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %% [markdown]
# Let start with how many male and female attend the survey

# %%
df['Gender'].value_counts()
# Out:
# Male                                                       11664
# Female                                                       970
# Other                                                         73
# Gender non-conforming                                         54
# Male; Other                                                   42
# Female; Transgender                                           28
# Transgender                                                   20
# Male; Gender non-conforming                                   19
# Female; Gender non-conforming                                 11
# Transgender; Gender non-conforming                             5
# Male; Female                                                   5
# Male; Transgender                                              4
# Male; Female; Transgender; Gender non-conforming; Other        4
# Female; Transgender; Gender non-conforming                     3
# ...

# %% [markdown]
# this

# %% [markdown]
# # Q1 I want to know How bootcamps assisting with increasing diversity in tech careers and How Bootcamp helping Job and Developers?

# %%
bootcamp_df=df[df['TimeAfterBootcamp'].isnull()==False]
nonbootcamp_df=df[df['TimeAfterBootcamp'].isnull()==True]

# %%
bootcamp_df
# Out:
#        Respondent                                       Professional  \
# 16             17                             Professional developer
# 40             41  Professional non-developer who sometimes write...
# 42             43                             Professional developer
# 54             55                             Professional developer
# 72             73                             Professional developer
# 83             84                             Professional developer
# 110           111                             Professional developer
# 145           146                             Professional developer
# 149           150                             Professional developer
# 228           229                                            Student
# 340           341                             Professional developer
# 347           348                             Professional developer
# 472           473                             Professional developer
# ...

# %%
bootcamp_df['TimeAfterBootcamp'] = bootcamp_df['TimeAfterBootcamp'].fillna(0.0)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# In above part I convert NaN values into 0 so jsut to make easy for your understanding

# %%
bootcamp_df['TimeAfterBootcamp'].value_counts()/bootcamp_df.shape[0]
# Out:
# I already had a job as a developer when I started the program    0.479592
# I got a job as a developer before completing the program         0.104308
# One to three months                                              0.096372
# Immediately upon graduating                                      0.095238
# I haven't gotten a job as a developer yet                        0.072562
# Less than a month                                                0.053288
# Four to six months                                               0.035147
# Six months to a year                                             0.032880
# Longer than a year                                               0.030612
# Name: TimeAfterBootcamp, dtype: float64

# %%
bootcamp_df['Salary'].value_counts()
# Out:
# 120000.000000    9
# 110000.000000    8
# 90000.000000     6
# 100000.000000    5
# 80000.000000     4
# 70000.000000     4
# 130000.000000    4
# 150000.000000    4
# 115000.000000    4
# 27956.989247     3
# 64516.129032     3
# 60000.000000     3
# 86021.505376     3
# 55000.000000     3
# 32258.064516     3
# 50000.000000     3
# 75000.000000     3
# 135000.000000    2
# 19108.280255     2
# 170000.000000    2
# 17618.558215     2
# 34408.602151     2
# 7341.065923      2
# 91397.849462     2
# 95000.000000     2
# 65000.000000     2
# 43750.000000     2
# 87331.536388     2
# 8809.279107      2
# 90909.090909     2
#                 ..
# 66666.666667     1
# 33333.333333     1
# 51000.000000     1
# 1431.297710      1
# 56561.085973     1
# 112903.225806    1
# 3234.501348      1
# 45801.526718     1
# 8064.516129      1
# 6606.959330      1
# 47800.000000     1
# 76500.000000     1
# 92500.000000     1
# 51515.151515     1
# 195000.000000    1
# 82000.000000     1
# ...

# %% [markdown]
# So we can see that person who attend bootcamp have there salary ranges from 9600 to 120000

# %%
bootcamp_df['Salary'].value_counts().plot(kind="hist");
plt.title("Bootcamp salary");

# %%
def color_plot(data_frame,title_choose):
    """ This function is  used to crete a bar chart with different colors"""
    data_frame.plot(kind="bar");
    plt.title(title_choose);

# %%
job_profile=((bootcamp_df['TimeAfterBootcamp'].value_counts()/bootcamp_df.shape[0])/df.shape[0])
color_plot(job_profile,"Bootcamp job profiles")

# %% [markdown]
# So We see that most of people who take Bootcamp are alerady developer and have Job
# So It is best practice and learn new thing for job and developer is to take Bootcamp which saves their precious time and motivate them

# %% [markdown]
# # Q2 What type of Web Developrs take survey ,What is the gradution level of Data Scientist and what language they used ?

# %%
web_devlopers=df['WebDeveloperType'].value_counts()

# %% [markdown]
# In this part we consider NaN value as 0 for Non categorical variable and note take part of our calculation and also
# We consider the value of categorical variable that are NaN are not part of our calculation

# %%
web_devlopers
# Out:
# Full stack Web developer    2729
# Back-end Web developer      1074
# Front-end Web developer      483
# Name: WebDeveloperType, dtype: int64

# %%
color_plot(web_devlopers,"Types of WebDeveloper")

# %% [markdown]
# So they are mostly Full Stack Web Developer are in the market but what language full stack web developer used?

# %%
web_dev=df[df['WebDeveloperType'].values=="Full stack Web developer"]

# %%
web_dev['HaveWorkedLanguage'].value_counts()
# Out:
# C#; JavaScript; SQL                                           174
# JavaScript; PHP; SQL                                          120
# Java; JavaScript                                               78
# Java; JavaScript; SQL                                          75
# JavaScript; PHP                                                72
# JavaScript                                                     66
# C#; JavaScript                                                 65
# C#; JavaScript; SQL; TypeScript                                62
# JavaScript; Python                                             33
# C#; JavaScript; TypeScript                                     30
# JavaScript; PHP; Python; SQL                                   30
# JavaScript; Ruby                                               26
# C#                                                             19
# Java; JavaScript; PHP; SQL                                     19
# ...

# %%
data_scientist=df[df['NonDeveloperType'].values=="Data scientist"]

# %%
data_scientist['FormalEducation'].value_counts()/data_scientist.shape[0]
# Out:
# Bachelor's degree                                                    0.312057
# Master's degree                                                      0.297872
# Doctoral degree                                                      0.241135
# Some college/university study without earning a bachelor's degree    0.085106
# Secondary school                                                     0.028369
# I prefer not to answer                                               0.021277
# Professional degree                                                  0.014184
# Name: FormalEducation, dtype: float64

# %%
def blue_plot(data_frame,title_choose):
    """ This function is  used to crete a bar chart with same colors I choose blue color"""
    data_frame.plot(kind="bar",color='blue');
    plt.title(title_choose);

# %%
educaton_ds = data_scientist['FormalEducation'].value_counts()
blue_plot(educaton_ds,"Formal Education of Data Scientist")

# %% [markdown]
# Now We can see person who are Data Scientist have Bachelors Degree and Master Degree and Bachelors are more means that they are not so much high qualification required to becom Data Scientist

# %%
data_scientist['HaveWorkedLanguage'].value_counts()
# Out:
# Python; R; SQL                                                              7
# Python; R                                                                   6
# Python                                                                      6
# R                                                                           6
# C; C++; Python                                                              4
# R; SQL                                                                      4
# Matlab; Python                                                              3
# Matlab; Python; R; SQL                                                      3
# JavaScript; PHP; SQL                                                        2
# Python; SQL                                                                 2
# JavaScript; Python; SQL                                                     2
# Python; SQL; VBA                                                            2
# ...

# %%
python_developer=df[df['HaveWorkedLanguage'].values=="Python"]
python_developer['NonDeveloperType'].value_counts()
# Out:
# Other                                           13
# Data scientist                                   6
# Analyst or consultant                            6
# Educator or academic                             4
# Analyst or consultant; Data scientist            2
# Analyst or consultant; Data scientist; Other     2
# Product manager                                  1
# Analyst or consultant; Other                     1
# Data scientist; Other                            1
# Educator or academic; Other                      1
# Data scientist; Educator or academic             1
# Analyst or consultant; Educator or academic      1
# Name: NonDeveloperType, dtype: int64

# %% [markdown]
# So we can see that most of python developer choose Data Scientist for their carrer very fue choose Analyst or Educator

# %% [markdown]
# No. of data scientist that uses Python for their work

# %%
len(data_scientist['HaveWorkedLanguage'].values=='Python')
# Out:
# 141

# %% [markdown]
# # Q3 What are the habits of developers like when they start their work , what are the remote developers timing and habits to do their daily work?

# %% [markdown]
# In this part we consider NaN value as 0 for Non categorical variable and note take part of our calculation and also
# We consider the value of categorical variable that are NaN are not part of our calculation

# %%
df['WorkStart'].value_counts()
# Out:
# 9:00 AM     3570
# 10:00 AM    3380
# 8:00 AM     2658
# 7:00 AM     1282
# 11:00 AM     772
# 6:00 AM      447
# Noon         385
# 1:00 PM      165
# 2:00 PM      160
# 4:00 PM       94
# 5:00 AM       92
# 8:00 PM       79
# 6:00 PM       67
# 3:00 PM       65
# 10:00 PM      64
# 9:00 PM       52
# 7:00 PM       38
# 4:00 AM       31
# 5:00 PM       28
# 11:00 PM      24
# Midnight      23
# 3:00 AM       18
# 1:00 AM       17
# 2:00 AM       12
# Name: WorkStart, dtype: int64

# %% [markdown]
# So We see that most of developer who take survey start their work at 9am,10am . I think that they are those who do work full time in office

# %% [markdown]
# what is the status of remote working

# %%
df['HomeRemote'].value_counts()
# Out:
# A few days each month                                      5876
# Never                                                      5288
# All or almost all the time (I'm full-time remote)          1922
# Less than half the time, but at least one day each week    1464
# More than half, but not all, the time                       676
# It's complicated                                            633
# About half the time                                         612
# Name: HomeRemote, dtype: int64

# %%
remote_work_people=df[df['HomeRemote'].values=="All or almost all the time (I'm full-time remote)"]

# %%
start_time_remote_dev=remote_work_people['WorkStart'].value_counts()
start_time_remote_dev
# Out:
# 10:00 AM    357
# 9:00 AM     321
# 8:00 AM     230
# 7:00 AM     133
# 11:00 AM     95
# 6:00 AM      59
# Noon         44
# 2:00 PM      29
# 5:00 AM      28
# 1:00 PM      26
# 4:00 PM      24
# 8:00 PM      20
# 9:00 PM      16
# 10:00 PM     14
# 3:00 PM      12
# 6:00 PM      10
# 4:00 AM       7
# Midnight      7
# 1:00 AM       4
# 7:00 PM       4
# 3:00 AM       4
# 5:00 PM       2
# 11:00 PM      1
# 2:00 AM       1
# Name: WorkStart, dtype: int64

# %%
blue_plot(start_time_remote_dev,"Work start by remote developer")

# %%
remote_work_people['WorkStart'].value_counts()/df['WorkStart'].value_counts()
# Out:
# 10:00 AM    0.105621
# 10:00 PM    0.218750
# 11:00 AM    0.123057
# 11:00 PM    0.041667
# 1:00 AM     0.235294
# 1:00 PM     0.157576
# 2:00 AM     0.083333
# 2:00 PM     0.181250
# 3:00 AM     0.222222
# 3:00 PM     0.184615
# 4:00 AM     0.225806
# 4:00 PM     0.255319
# 5:00 AM     0.304348
# 5:00 PM     0.071429
# 6:00 AM     0.131991
# 6:00 PM     0.149254
# 7:00 AM     0.103744
# 7:00 PM     0.105263
# 8:00 AM     0.086531
# 8:00 PM     0.253165
# 9:00 AM     0.089916
# 9:00 PM     0.307692
# Midnight    0.304348
# Noon        0.114286
# Name: WorkStart, dtype: float64

# %%
comparison_remote_time=remote_work_people['WorkStart'].value_counts()/df['WorkStart'].value_counts()
blue_plot(comparison_remote_time,"Comparison of working hours of Remote working people")

# %% [markdown]
# So we see most of the remote workers prefer to start their work at 10am,9am and 8am but comparison to those who work full time rmote developer are in large no. who like to start their work at 5 am, 9 pm,10 pm and midnight
# But How many of them are profesional ?

# %%
remote_work_people['Professional'].value_counts()
# Out:
# Professional developer                                  1546
# Student                                                  173
# Professional non-developer who sometimes writes code     169
# Used to be a professional developer                       34
# Name: Professional, dtype: int64

# %%
remote_work_people['Professional'].value_counts()/remote_work_people.shape[0]
# Out:
# Professional developer                                  0.804370
# Student                                                 0.090010
# Professional non-developer who sometimes writes code    0.087929
# Used to be a professional developer                     0.017690
# Name: Professional, dtype: float64

# %% [markdown]
# Remote working people are mostly Professional developer that is about 80%
